# %% [markdown]
# # Rede Neural – Classificação de Imagens

# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
import pathlib

data_dir = tf.keras.utils.get_file(origin='https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
                                  fname='flower_photos', untar=True)
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
#diretorios das imagens
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != 'LICENSE.txt'])
CLASS_NAMES
# Out:
# array(['tulips', 'dandelion', 'sunflowers', 'daisy', 'roses'],
#       dtype='<U10')

# %%
#carregando algumas rosas
roses = list(data_dir.glob('roses/*'))

for image_path in roses[:3]:
    display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F54858BAC90>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=184x240 at 0x7F5485896450>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F54858965D0>

# %%
#carregando as imagens com keras
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
#definindo alguns parametros para carga
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)

# %%
train_data_gen = image_generator.flow_from_directory(directory=str(data_dir),
                                                    batch_size=BATCH_SIZE,
                                                    shuffle=True,
                                                    target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                    classes=list(CLASS_NAMES))
# Out:
# Found 3670 images belonging to 5 classes.

# %%
#inspecione o lote
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
        plt.axis('off')

# %%
image_batch, label_batch = next(train_data_gen)
show_batch(image_batch, label_batch)

# %%
#carregando usando tf.data
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*'))

# %%
for f in list_ds.take(5):
    print(f.numpy())
# Out:
# b'/home/danilo/.keras/datasets/flower_photos/sunflowers/22183521655_56221bf2a4_n.jpg'
# b'/home/danilo/.keras/datasets/flower_photos/daisy/4258408909_b7cc92741c_m.jpg'
# b'/home/danilo/.keras/datasets/flower_photos/daisy/1344985627_c3115e2d71_n.jpg'
# b'/home/danilo/.keras/datasets/flower_photos/sunflowers/2729206569_9dd2b5a3ed.jpg'
# b'/home/danilo/.keras/datasets/flower_photos/sunflowers/6199086734_b7ddc65816_m.jpg'

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == CLASS_NAMES

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
labeled_ds = list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in labeled_ds.take(1):
    print(f"Image shape: {image.numpy().shape}")
    print(f"Label: {label.numpy()}")
# Out:
# Image shape: (224, 224, 3)
# Label: [False False False False  True]

# %%
def prepare_for_traing(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

# %%
train_ds = prepare_for_traing(labeled_ds)

image_batch, label_batch = next(iter(train_ds))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
import time
default_timeit_steps = 1000

def timeit(ds, steps=default_timeit_steps):
    start = time.time()
    it = iter(ds)
    for i in range(steps):
        batch = next(it)
        if i%10 == 0:
            print('.',end='')
    print()
    end = time.time()
    
    duration = end-start
    print(f"{steps} batches: {duration} s")
    print(f"{BATCH_SIZE*steps/duration:0.5f} Images/s")

# %%
timeit(train_data_gen)
# Out:
# ....................................................................................................
# 1000 batches: 59.62348699569702 s
# 536.70125 Images/s

# %%
timeit(train_ds)
# Out:
# ....................................................................................................
# 1000 batches: 3.4651896953582764 s
# 9234.70367 Images/s

# %%
# Grande parte do ganho de desempenho vem do uso de cache
uncached_ds = prepare_for_traing(labeled_ds, cache=False)
timeit(uncached_ds)
# Out:
# ....................................................................................................
# 1000 batches: 12.042948961257935 s
# 2657.15649 Images/s

# %%
#usando um arquivo de cache
filecache_ds = prepare_for_traing(labeled_ds, cache="./flowers.tfcache")
timeit(filecache_ds)
# Out:
# ....................................................................................................
# 1000 batches: 7.390525579452515 s
# 4329.86797 Images/s
